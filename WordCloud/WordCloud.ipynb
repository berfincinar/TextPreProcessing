# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from texthero import preprocessing
import texthero as hero
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cols = [6]
df1= pd.read_excel('Release_Notes.xlsx',usecols=cols,sheet_name=['Sayfa1'])

df1
# Out:
# {'Sayfa1':                                                   Note
#  0                                         Security fix
#  1                                Developer Information
#  2    Native support for macOS devices built with Ap...
#  3                               Various security fixes
#  4    Various bug fixes and new policies have been i...
#  ..                                                 ...
#  784  Fixed: A few rare crashes when making a call a...
#  785  You're nearly finished signing in when suddenl...
#  786  File downloads are now pausable and – in perha...
#  787  On Windows 7, notifications have been made mor...
#  788  The certificate used by Windows to confirm tha...
#
#  [789 rows x 1 columns]}

# %%
dfc=df1.copy()
dfc=pd.concat(df1[frame] for frame in df1.keys())
dfc
df=pd.DataFrame()
df['Note']=dfc['Note']

# %%
custom_pipeline = [preprocessing.fillna,
                   preprocessing.lowercase,
                   preprocessing.remove_whitespace,
                   preprocessing.remove_stopwords,
                   preprocessing.remove_diacritics,
                   preprocessing.remove_punctuation,
                   preprocessing.remove_digits]

df['Note'] = hero.clean(df['Note'], custom_pipeline)
df
# Out:
#                                                   Note
# 0                                         security fix
# 1                                developer information
# 2    native support macos devices built apple silic...
# 3                               various security fixes
# 4    various bug fixes new policies implemented lat...
# ..                                                 ...
# 784  fixed rare crashes making call screen sharing ...
# 785  nearly finished signing suddenly bonk brought ...
# 786  file downloads pausable perhaps master stroke ...
# 787  windows notifications made reliable expense pr...
# 788  certificate used windows confirm slack truly s...
#
# [789 rows x 1 columns]

# %%
print("There are {} observations and {} features in this dataset. \n".format(df.shape[0],df.shape[1]))
# Out:
# There are 789 observations and 1 features in this dataset.

# %%
# ?WordCloud
# Out:
# Init signature:
# WordCloud(
#     font_path=None,
#     width=400,
#     height=200,
#     margin=2,
#     ranks_only=None,
#     prefer_horizontal=0.9,
#     mask=None,
#     scale=1,
#     color_func=None,
#     max_words=200,
#     min_font_size=4,
#     stopwords=None,
#     random_state=None,
#     background_color='black',
#     max_font_size=None,
#     font_step=1,
#     mode='RGB',
#     relative_scaling='auto',
#     regexp=None,
#     collocations=True,
#     colormap=None,
#     normalize_plurals=True,
#     contour_width=0,
#     contour_color='black',
#     repeat=False,
#     include_numbers=False,
#     min_word_length=0,
#     collocation_threshold=30,
# )
# Docstring:
# Word cloud object for generating and drawing.
#
# Parameters
# ----------
# font_path : string
#     Font path to the font that will be used (OTF or TTF).
#     Defaults to DroidSansMono path on a Linux machine. If you are on
#     another OS or don't have this font, you need to adjust this path.
#
# ...

# %%
file = open("test_file.txt", encoding="utf8")

# %%
data = file.read()

# %%
textt=data

# %%
wordcloud = WordCloud().generate(textt)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("first_review.png")

# %%
wordcloud = WordCloud(width=1980,
    height=1020,max_words=100, background_color="white").generate(textt)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("first_review_100.png")

# %%
wordcloud = WordCloud(width=1980,
    height=1020,max_words=1000, background_color="white").generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("first_review_1000.png")
